# %% [markdown]
# <a href="https://colab.research.google.com/github/KritishBokde91/NNDL_LAB/blob/main/NNDL_PRACTICAL1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas

# %%
import numpy as np
import pandas as pd
from google.colab import drive, files
import io

# %%
#Vector Addition
vector1 = np.array([5, 10, 15])
vector2 = np.array([1, 8, 21])

result1 = vector1 + vector2
print(result1)
# Out:
# [ 6 18 36]

# %%
#Vector Multiplication
vector3 = np.array([[15, 30, 16], [25, 50, 27], [12, 18, 40]])
vector4 = np.array([[1, 16, 25], [88, 76, 4], [18, 36, 77]])

result2 = np.matmul(vector3, vector4)
print(result2)
# Out:
# [[2943 3096 1727]
#  [4911 5172 2904]
#  [2316 3000 3452]]

# %%
#Read CSV File using Pandas
data = pd.read_csv("/content/sample_data/movie_dataset.csv")
data.head()
# Out:
#         id                             title original_language  \
# 0    13448                   Angels & Demons                en
# 1     9603                          Clueless                en
# 2     6557                        27 Dresses                en
# 3  1333100  Attack on Titan: THE LAST ATTACK                ja
# 4   578701            Those Who Wish Me Dead                en
#
#                   original_title  \
# 0                Angels & Demons
# 1                       Clueless
# 2                     27 Dresses
# 3  劇場版「進撃の巨人」完結編 THE LAST ATTACK
# 4         Those Who Wish Me Dead
#
#                                             overview release_date  popularity  \
# 0  Harvard symbologist Robert Langdon is recruite...   2009-04-20      6.8861
# 1  Shallow, rich and socially successful Cher is ...   1995-07-19      7.5190
# 2  Altruistic Jane finds herself facing her worst...   2008-01-10      5.7786
# ...

# %%
#Read CSV File using Drive
drive.mount("/content/drive")
dataset = pd.read_csv('/content/drive/MyDrive/NNDL_LAB/movie_dataset.csv')
dataset.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         id                             title original_language  \
# 0    13448                   Angels & Demons                en
# 1     9603                          Clueless                en
# 2     6557                        27 Dresses                en
# 3  1333100  Attack on Titan: THE LAST ATTACK                ja
# 4   578701            Those Who Wish Me Dead                en
#
#                   original_title  \
# 0                Angels & Demons
# 1                       Clueless
# 2                     27 Dresses
# 3  劇場版「進撃の巨人」完結編 THE LAST ATTACK
# 4         Those Who Wish Me Dead
#
#                                             overview release_date  popularity  \
# 0  Harvard symbologist Robert Langdon is recruite...   2009-04-20      6.8861
# 1  Shallow, rich and socially successful Cher is ...   1995-07-19      7.5190
# ...

# %%
#Read CSV File using Python Files
uploaded = files.upload()
data2 = pd.read_csv("/content/movie_dataset.csv")
data2.head()
# Out:
#      <input type="file" id="files-b4623958-964a-48ef-9e7f-0e124945cfe4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4623958-964a-48ef-9e7f-0e124945cfe4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Read CSV File using Kaggle Dataset
